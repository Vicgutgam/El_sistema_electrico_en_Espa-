# %%
import pandas as pd

# %%
data = pd.read_csv('Custom-Report-2024-02-01-Seguimiento de la demanda de energía eléctrica (MW).csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 data = pd.read_csv('Custom-Report-2024-02-01-Seguimiento de la demanda de energía eléctrica (MW).csv')
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
data

# %%
Spain = data[data['CountryLong'] == 'Spain']
Spain
# Out:
#     CountryShort CountryLong  Year  ValueNumeric      Unit Data_source
# 756           ES       Spain  1990    448.456832  gCO2/kWh         EEA
# 757           ES       Spain  1991    443.562676  gCO2/kWh         EEA
# 758           ES       Spain  1992    485.006645  gCO2/kWh         EEA
# 759           ES       Spain  1993    457.257521  gCO2/kWh         EEA
# 760           ES       Spain  1994    449.599298  gCO2/kWh         EEA
# 761           ES       Spain  1995    495.821395  gCO2/kWh         EEA
# 762           ES       Spain  1996    387.819671  gCO2/kWh         EEA
# 763           ES       Spain  1997    427.349854  gCO2/kWh         EEA
# 764           ES       Spain  1998    424.435009  gCO2/kWh         EEA
# 765           ES       Spain  1999    499.692422  gCO2/kWh         EEA
# 766           ES       Spain  2000    466.540220  gCO2/kWh         EEA
# 767           ES       Spain  2001    415.966877  gCO2/kWh         EEA
# ...

# %%
data.head(30)
# Out:
#     Unnamed: 0    Unnamed: 0_level_0   2016 Unnamed: 3   2017 Unnamed: 5  \
# 0          NaN  Country or territory    New      Total    New      Total
# 1          0.0                 China  34540      78070  53000     131000
# 2          1.0        European Union    NaN     101433   5717     107150
# 3          2.0         United States  14730      40300  10600      51000
# 4          3.0                 Japan   8600      42750   7000      49000
# 5          4.0               Germany   1520      41220   1800      42000
# 6          5.0                 India   3970       9010   9100      18300
# 7          6.0                 Italy    373      19279    409      19700
# 8          7.0             Australia    839       5900   1250       7200
# 9          8.0           South Korea    850       4350   1200       5600
# 10         9.0               Vietnam    NaN          6      3          9
# 11        10.0             Spain[27]    NaN       4669     19       4688
# ...

# %%
artworks['Catalogue'].value_counts()
# Out:
# Catalogue
# Y    71333
# N    58929
# Name: count, dtype: int64
