# %% [markdown]
# <h2 style="color:#e39714"> 🧰 Tools: 🧰 </h2> </center>

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import HTML

from urllib.request import urlopen
import requests
from bs4 import BeautifulSoup
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# <h2 style="color:#e39714"> 🧰 Producción solar mundial: 🧰 </h2> </center>

# %%
data = pd.read_csv('Solar Power Energy  by Country.csv')
solar = data.copy()

# %%
#Eliminar filas innecesarias
solar = solar.fillna(0)
solar = solar.drop(['2019.1', '2021.1','Share of totalconsumption','Unnamed: 0'], axis=1)
solar = solar.drop(index=0, axis=0)
solar = solar.dropna()

#Renombrar columnas
solar.rename(columns={'Unnamed: 13': 'Total_final'}, inplace=True)
solar.rename(columns={'Unnamed: 3': 'Total_2016'}, inplace=True)
solar.rename(columns={'Unnamed: 5': 'Total_2017'}, inplace=True)
solar.rename(columns={'Unnamed: 7': 'Total_2018'}, inplace=True)
solar.rename(columns={'Unnamed: 9': 'Total_2019'}, inplace=True)
solar.rename(columns={'Unnamed: 11': 'Total_2020'}, inplace=True)

solar.rename(columns={'2016': 'Nuevo_2016'}, inplace=True)
solar.rename(columns={'2017': 'Nuevo_2017'}, inplace=True)
solar.rename(columns={'2018': 'Nuevo_2018'}, inplace=True)
solar.rename(columns={'2019': 'Nuevo_2019'}, inplace=True)
solar.rename(columns={'2020': 'Nuevo_2020'}, inplace=True)
solar.rename(columns={'2021': 'Nuevo_2021'}, inplace=True)


#Fijamos la primera columna como índice y la ponemos en snake case y minúscula. Pasamos a Float
solar.set_index(solar.columns[0], inplace=True)
solar = solar.apply(pd.to_numeric, errors='coerce').astype(float)

# %% [markdown]
# ## Representación de los mayores productores de Energía solar

# %%
solar15 = solar.head(20)

total_final_column = solar15['Total_2016']

# Crear el histograma con el índice como eje x
plt.barh(solar15.index, total_final_column, color=['red', 'green', 'blue', 'yellow', 'orange', 'purple', 'pink', 'brown', 'cyan', 'magenta', 'lime', 'teal', 'lavender', 'maroon', 'navy', 'olive', 'silver', 'black', 'white', 'gray'])

# Etiquetas y título
plt.xlabel('Total Final')
plt.ylabel('País')
plt.title('Energía solar producida 2016')

# Rotar etiquetas del eje x para mayor legibilidad
plt.xticks(rotation=90)

# Mostrar el histograma
plt.tight_layout()
plt.show()

# %%
solar15 = solar.head(20)

total_final_column = solar15['Total_final']

# Crear el histograma con el índice como eje x
plt.barh(solar15.index, total_final_column, color=['red', 'green', 'blue', 'yellow', 'orange', 'purple', 'pink', 'brown', 'cyan', 'magenta', 'lime', 'teal', 'lavender', 'maroon', 'navy', 'olive', 'silver', 'black', 'white', 'gray'])

# Etiquetas y título
plt.xlabel('Total Final')
plt.ylabel('País')
plt.title('Energía solar producida 2021')

# Rotar etiquetas del eje x para mayor legibilidad
plt.xticks(rotation=90)

# Mostrar el histograma
plt.tight_layout()
plt.show()

# %%
solar.describe()
# Out:
#          Nuevo_2016     Total_2016    Nuevo_2017     Total_2017    Nuevo_2018  \
# count     92.000000      92.000000     92.000000      92.000000     92.000000
# mean    1632.489130    7646.489130   2111.086957    9758.728261   1120.457609
# std     8872.488521   34903.521241  11347.643172   45570.701389   5022.341008
# min        0.000000       0.000000      0.000000       0.000000      0.000000
# 25%        0.000000      36.750000      0.000000      46.500000      0.000000
# 50%        0.000000      95.000000      0.000000     184.500000      0.000000
# 75%      106.750000    1040.250000    150.750000    1281.000000    114.500000
# max    76800.000000  306500.000000  95000.000000  401500.000000  45000.000000
#
#           Total_2018    Nuevo_2019     Total_2019    Nuevo_2020  \
# count      92.000000     92.000000      92.000000      92.00000
# mean    12064.369565   1192.793478   14069.163043    2985.26087
# std     57453.534910   3995.634287   65608.993622   14912.43155
# ...
